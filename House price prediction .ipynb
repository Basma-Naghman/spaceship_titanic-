# %%
import pandas as pd

# %%
import numpy as np

# %%
df_test = pd.read_csv("test (1).csv")

# %%
df_train = pd.read_csv("train (1).csv")

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train = df_train.drop(columns = ["Alley","MasVnrType","FireplaceQu","PoolQC","Fence","MiscFeature","Id","MSSubClass","MSZoning","LotFrontage","Utilities","LotConfig","Exterior2nd","MasVnrType","MasVnrArea","Foundation","BsmtFinType1","BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF","LowQualFinSF","GrLivArea","BsmtFullBath","BsmtHalfBath","FullBath","HalfBath","KitchenQual","TotRmsAbvGrd","Functional","GarageType","GarageYrBlt","GarageFinish","GarageCars","GarageArea","GarageQual","GarageCond","PavedDrive","WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","PoolQC","Fence","MiscFeature","MiscVal","MoSold","SaleType","SaleCondition"])

# %%
train
# Out:
#       LotArea Street LotShape LandContour LandSlope Neighborhood Condition1  \
# 0        8450   Pave      Reg         Lvl       Gtl      CollgCr       Norm
# 1        9600   Pave      Reg         Lvl       Gtl      Veenker      Feedr
# 2       11250   Pave      IR1         Lvl       Gtl      CollgCr       Norm
# 3        9550   Pave      IR1         Lvl       Gtl      Crawfor       Norm
# 4       14260   Pave      IR1         Lvl       Gtl      NoRidge       Norm
# ...       ...    ...      ...         ...       ...          ...        ...
# 1455     7917   Pave      Reg         Lvl       Gtl      Gilbert       Norm
# 1456    13175   Pave      Reg         Lvl       Gtl       NWAmes       Norm
# 1457     9042   Pave      Reg         Lvl       Gtl      Crawfor       Norm
# 1458     9717   Pave      Reg         Lvl       Gtl        NAmes       Norm
# 1459     9937   Pave      Reg         Lvl       Gtl      Edwards       Norm
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   Street        1460 non-null   object
#  2   LotShape      1460 non-null   object
#  3   LandContour   1460 non-null   object
#  4   LandSlope     1460 non-null   object
#  5   Neighborhood  1460 non-null   object
#  6   Condition1    1460 non-null   object
#  7   Condition2    1460 non-null   object
#  8   BldgType      1460 non-null   object
#  9   HouseStyle    1460 non-null   object
#  10  OverallQual   1460 non-null   int64
#  11  OverallCond   1460 non-null   int64
#  12  YearBuilt     1460 non-null   int64
#  13  YearRemodAdd  1460 non-null   int64
#  14  RoofStyle     1460 non-null   object
#  15  RoofMatl      1460 non-null   object
#  16  Exterior1st   1460 non-null   object
#  17  ExterQual     1460 non-null   object
# ...

# %%
def remove_null_object(column):
    for i in column:
        train[i] = train[i].fillna(train[i].mode()[0])
columns = ["BsmtQual","BsmtCond","BsmtExposure","Electrical"]
remove_null_object(columns)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   Street        1460 non-null   object
#  2   LotShape      1460 non-null   object
#  3   LandContour   1460 non-null   object
#  4   LandSlope     1460 non-null   object
#  5   Neighborhood  1460 non-null   object
#  6   Condition1    1460 non-null   object
#  7   Condition2    1460 non-null   object
#  8   BldgType      1460 non-null   object
#  9   HouseStyle    1460 non-null   object
#  10  OverallQual   1460 non-null   int64
#  11  OverallCond   1460 non-null   int64
#  12  YearBuilt     1460 non-null   int64
#  13  YearRemodAdd  1460 non-null   int64
#  14  RoofStyle     1460 non-null   object
#  15  RoofMatl      1460 non-null   object
#  16  Exterior1st   1460 non-null   object
#  17  ExterQual     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def convert_object_to_int(column):
    for i in column:
        df_label_encoder = LabelEncoder()
        train[i] = df_label_encoder.fit_transform(train[i])
columns = ["Street","LotShape","LandContour","LandSlope","Neighborhood","Condition1","Condition2","BldgType","HouseStyle","RoofStyle","RoofMatl","Exterior1st","ExterQual","ExterCond","BsmtQual","BsmtCond","BsmtExposure","Heating","HeatingQC","CentralAir","Electrical"]
convert_object_to_int(columns)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   Street        1460 non-null   int64
#  2   LotShape      1460 non-null   int64
#  3   LandContour   1460 non-null   int64
#  4   LandSlope     1460 non-null   int64
#  5   Neighborhood  1460 non-null   int64
#  6   Condition1    1460 non-null   int64
#  7   Condition2    1460 non-null   int64
#  8   BldgType      1460 non-null   int64
#  9   HouseStyle    1460 non-null   int64
#  10  OverallQual   1460 non-null   int64
#  11  OverallCond   1460 non-null   int64
#  12  YearBuilt     1460 non-null   int64
#  13  YearRemodAdd  1460 non-null   int64
#  14  RoofStyle     1460 non-null   int64
#  15  RoofMatl      1460 non-null   int64
#  16  Exterior1st   1460 non-null   int64
#  17  ExterQual     1460 non-null   int64
# ...

# %%
train
# Out:
#       LotArea  Street  LotShape  LandContour  LandSlope  Neighborhood  \
# 0        8450       1         3            3          0             5
# 1        9600       1         3            3          0            24
# 2       11250       1         0            3          0             5
# 3        9550       1         0            3          0             6
# 4       14260       1         0            3          0            15
# ...       ...     ...       ...          ...        ...           ...
# 1455     7917       1         3            3          0             8
# 1456    13175       1         3            3          0            14
# 1457     9042       1         3            3          0             6
# 1458     9717       1         3            3          0            12
# 1459     9937       1         3            3          0             7
#
#       Condition1  Condition2  BldgType  HouseStyle  ...  CentralAir  \
# ...

# %%
x = train.iloc[:,:34]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x
# Out:
#       LotArea  Street  LotShape  LandContour  LandSlope  Neighborhood  \
# 0        8450       1         3            3          0             5
# 1        9600       1         3            3          0            24
# 2       11250       1         0            3          0             5
# 3        9550       1         0            3          0             6
# 4       14260       1         0            3          0            15
# ...       ...     ...       ...          ...        ...           ...
# 1455     7917       1         3            3          0             8
# 1456    13175       1         3            3          0            14
# 1457     9042       1         3            3          0             6
# 1458     9717       1         3            3          0            12
# 1459     9937       1         3            3          0             7
#
#       Condition1  Condition2  BldgType  HouseStyle  ...  HeatingQC  \
# ...

# %%
y = train["SalePrice"]

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
model1 = RandomForestClassifier()

# %%
model1.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
test = df_test.drop(columns = ["Alley","MasVnrType","FireplaceQu","PoolQC","Fence","MiscFeature","Id","MSSubClass","MSZoning","LotFrontage","Utilities","LotConfig","Exterior2nd","MasVnrType","MasVnrArea","Foundation","BsmtFinType1","BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF","LowQualFinSF","GrLivArea","BsmtFullBath","BsmtHalfBath","FullBath","HalfBath","KitchenQual","TotRmsAbvGrd","Functional","GarageType","GarageYrBlt","GarageFinish","GarageCars","GarageArea","GarageQual","GarageCond","PavedDrive","WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","PoolQC","Fence","MiscFeature","MiscVal","MoSold","SaleType","SaleCondition"])

# %%
def remove_null_object(column):
    for i in column:
        test[i] = test[i].fillna(test[i].mode()[0])
columns = ["BsmtQual","BsmtCond","BsmtExposure","Electrical","TotalBsmtSF"]
remove_null_object(columns)

# %%
def convert_object_to_int(column):
    for i in column:
        df_label_encoder = LabelEncoder()
        test[i] = df_label_encoder.fit_transform(test[i])
columns = ["Street","LotShape","LandContour","LandSlope","Neighborhood","Condition1","Condition2","BldgType","HouseStyle","RoofStyle","RoofMatl","Exterior1st","ExterQual","ExterCond","BsmtQual","BsmtCond","BsmtExposure","Heating","HeatingQC","CentralAir","Electrical","TotalBsmtSF"]
convert_object_to_int(columns)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1459 non-null   int64
#  1   Street        1459 non-null   int64
#  2   LotShape      1459 non-null   int64
#  3   LandContour   1459 non-null   int64
#  4   LandSlope     1459 non-null   int64
#  5   Neighborhood  1459 non-null   int64
#  6   Condition1    1459 non-null   int64
#  7   Condition2    1459 non-null   int64
#  8   BldgType      1459 non-null   int64
#  9   HouseStyle    1459 non-null   int64
#  10  OverallQual   1459 non-null   int64
#  11  OverallCond   1459 non-null   int64
#  12  YearBuilt     1459 non-null   int64
#  13  YearRemodAdd  1459 non-null   int64
#  14  RoofStyle     1459 non-null   int64
#  15  RoofMatl      1459 non-null   int64
#  16  Exterior1st   1459 non-null   int64
#  17  ExterQual     1459 non-null   int64
# ...

# %%
y_pred = model1.predict(test)
# Calculate RMSE

# %%
# Id,SalePrice

te = pd.read_csv("test (1).csv")
te['Id']
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
submission = pd.DataFrame({'Id':te['Id'],'SalePrice':y_pred})

# %%
submission.to_csv('submitted.csv',index=False)
